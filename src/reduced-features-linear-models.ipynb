# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import gc, time, warnings, joblib, pickle
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
from itertools import combinations
from warnings import simplefilter

pd.set_option('display.float_format', lambda x: '%.4f' % x)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)

warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
# Out:
# /kaggle/input/data1030-optiver-trading-at-close/test_dataset.pkl
# /kaggle/input/data1030-optiver-trading-at-close/train_val_dataset.pkl

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_absolute_error

from mlxtend.evaluate.time_series import (
    GroupTimeSeriesSplit,
    plot_splits,
    print_cv_info,
    print_split_info,
)

# %%
# Load Data
data_folder = '/kaggle/input/data1030-optiver-trading-at-close/'
# data_folder = '../data/preprocessed/'

with open(os.path.join(data_folder, 'train_val_dataset.pkl'), 'rb') as file:
    train_val_dataset = pickle.load(file)
    
with open(os.path.join(data_folder, 'test_dataset.pkl'), 'rb') as file:
    test_dataset = pickle.load(file)

X_other, y_other, groups_other = train_val_dataset['X_other'], train_val_dataset['y_other'], train_val_dataset['groups_other']
X_test, y_test, groups_test, submission_id = test_dataset['X_test'], test_dataset['y_test'], test_dataset['groups_test'], test_dataset['submission_id']

# collect which encoder to use on each feature
onehot_ftrs = ['imbalance_buy_sell_flag', 'stock_id']
std_ftrs = ['seconds_in_bucket', 'imbalance_size', 'reference_price', 'matched_size', 
            'far_price', 'near_price', 'bid_price', 'bid_size', 'ask_price', 'ask_size', 
            'wap', 'lagged_target_1d_0', 'lagged_target_1d_10', 'lagged_target_1d_20', 
            'lagged_target_1d_30', 'lagged_target_1d_40', 'lagged_target_1d_50', 
            'lagged_target_1d_60', 'lagged_target_1d_70', 'lagged_target_1d_80', 
            'lagged_target_1d_90', 'lagged_target_1d_100', 'lagged_target_1d_110', 
            'lagged_target_1d_120', 'lagged_target_1d_130', 'lagged_target_1d_140', 
            'lagged_target_1d_150', 'lagged_target_1d_160', 'lagged_target_1d_170', 
            'lagged_target_1d_180', 'lagged_target_1d_190', 'lagged_target_1d_200', 
            'lagged_target_1d_210', 'lagged_target_1d_220', 'lagged_target_1d_230', 
            'lagged_target_1d_240', 'lagged_target_1d_250', 'lagged_target_1d_260', 
            'lagged_target_1d_270', 'lagged_target_1d_280', 'lagged_target_1d_290', 
            'lagged_target_1d_300', 'lagged_target_1d_310', 'lagged_target_1d_320', 
            'lagged_target_1d_330', 'lagged_target_1d_340', 'lagged_target_1d_350', 
            'lagged_target_1d_360', 'lagged_target_1d_370', 'lagged_target_1d_380', 
            'lagged_target_1d_390', 'lagged_target_1d_400', 'lagged_target_1d_410', 
            'lagged_target_1d_420', 'lagged_target_1d_430', 'lagged_target_1d_440', 
            'lagged_target_1d_450', 'lagged_target_1d_460', 'lagged_target_1d_470', 
            'lagged_target_1d_480', 'lagged_target_1d_490', 'lagged_target_1d_500', 
            'lagged_target_1d_510', 'lagged_target_1d_520', 'lagged_target_1d_530', 
            'lagged_target_1d_540', 'volume', 'mid_price', 'liquidity_imbalance', 
            'matched_imbalance', 'size_imbalance', 'reference_price_far_price_imb', 
            'reference_price_near_price_imb', 'reference_price_ask_price_imb', 
            'reference_price_bid_price_imb', 'reference_price_wap_imb', 'far_price_near_price_imb', 
            'far_price_ask_price_imb', 'far_price_bid_price_imb', 'far_price_wap_imb', 
            'near_price_ask_price_imb', 'near_price_bid_price_imb', 'near_price_wap_imb', 
            'ask_price_bid_price_imb', 'ask_price_wap_imb', 'bid_price_wap_imb', 'price_spread', 
            'price_pressure', 'market_urgency', 'depth_pressure', 'all_prices_mean', 
            'all_sizes_mean', 'all_prices_std', 'all_sizes_std', 'all_prices_skew', 
            'all_sizes_skew', 'all_prices_kurt', 'all_sizes_kurt', 'dow', 'seconds', 'minute']

# collect all the encoders
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(sparse_output=False,handle_unknown='ignore'), onehot_ftrs),
        ('std', StandardScaler(), std_ftrs)])

model_save_path = 'result'
if not os.path.exists(model_save_path):
    os.makedirs(model_save_path)
    
result_path = '/kaggle/working/result/'
# result_path = '../result/'

# %% [markdown]
# # Pipeline

# %%
from  sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
def MLpipe_reduced_feature(X_other, y_other, groups_other, X_test, y_test, groups_test,
                           preprocessor, model, param_grid, path, model_Name):
    prep = Pipeline(steps=[('preprocessor', preprocessor)])

    n_split = 4
    count = 0
    test_scores = np.zeros(n_split)
    pred_results = []

    # Split train-val data
    len_group_other = groups_other.nunique()
    gts = GroupTimeSeriesSplit(test_size=int(len_group_other*0.25), n_splits=n_split)

    for i_train, i_val in gts.split(X_other, y_other, groups_other):
        print(f'\nFold {count+1} Reduced Features:')
        best_models = []
        
        print("\t Train index:", i_train, "Val index:", i_val)
        print("\t Train size:", len(i_train), "Val size:", len(i_val))
        X_train, y_train, groups_train = X_other.iloc[i_train], y_other.iloc[i_train], groups_other.iloc[i_train]
        X_val, y_val, groups_val = X_other.iloc[i_val], y_other.iloc[i_val], groups_other.iloc[i_val]
        
        X_train_preprocessed = prep.fit_transform(X_train)
        feature_names = prep.get_feature_names_out()
        
        # parameter Searching
        pg = ParameterGrid(param_grid)
        scores = np.zeros(len(pg))
        
        print('\t Preparing datasets...')
        df_train = pd.DataFrame(data = X_train_preprocessed, columns = feature_names, index=y_train.index)
        del X_train_preprocessed, X_train
        gc.collect()
        
        X_val_preprocessed = prep.transform(X_val)
        df_val = pd.DataFrame(data = X_val_preprocessed, columns = feature_names, index=y_val.index)
        del X_val_preprocessed, X_val
        gc.collect()
        
        X_test_preprocessed = prep.transform(X_test)
        df_test = pd.DataFrame(data = X_test_preprocessed, columns = feature_names, index=y_test.index)

        # Free up memory
        del X_test_preprocessed
        gc.collect()

        # reduced feature
        # find all unique patterns of missing value in test set
        mask = df_test.isnull()
        unique_rows = np.array(np.unique(mask, axis=0))
        all_y_test_pred = pd.DataFrame()
        print('\t there are', len(unique_rows), 'unique missing value patterns.')

        # divide test sets into subgroups according to the unique patterns
        for i in range(len(unique_rows)):
            print ('\t working on unique pattern', i)
            ## generate X_test subset that matches the unique pattern i: optimized code
            index_subset = df_test[mask.eq(unique_rows[i], axis=1).all(axis=1)].index
            sub_X_test = df_test.loc[index_subset] 
            sub_X_test = sub_X_test[df_test.columns[~unique_rows[i]]] # drop nan columns
            sub_y_test = y_test.loc[index_subset]

            ## prepare train-val subset
            # 1.cut the feature columns that have nans in the according sub_X_test
            sub_X_train = df_train[df_train.columns[~unique_rows[i]]].copy()
            sub_X_val = df_val[df_val.columns[~unique_rows[i]]].copy()
            # 2.cut the rows in the sub_X_train and sub_X_CV that have any nans
            sub_X_train = sub_X_train.dropna()
            sub_X_val = sub_X_val.dropna()   
            # 3.cut the sub_Y_train and sub_y_CV accordingly
            sub_y_train = y_train.loc[sub_X_train.index]
            sub_y_val = y_val.loc[sub_X_val.index]

            # run ML algo
            # change to 1-D array
            sub_y_train_array = sub_y_train.values.ravel()
            sub_y_val_array = sub_y_val.values.ravel()
            sub_y_test_array = sub_y_test.values.ravel()

            # run model
            ML_algo = model
            pg = ParameterGrid(param_grid)
            val_scores = np.zeros(len(pg))
                
            for p in range(len(pg)):
                params = pg[p]
                print('\t\t params:', params)
                ML_algo.set_params(**params)
                ML_algo.fit(sub_X_train, sub_y_train_array)
                sub_y_val_pred = ML_algo.predict(sub_X_val)
                val_scores[p] = mean_absolute_error(sub_y_val_array, sub_y_val_pred)
                print('\t\t val_score:', val_scores[p])
            
            best_params = np.array(pg)[val_scores == np.min(val_scores)]
            print(f'\t best model parameters for pattern {i}:\n', best_params)
            print('\t corresponding validation score:', np.min(val_scores))
                
            ML_algo.set_params(**best_params[0])
            ML_algo.fit(sub_X_train, sub_y_train_array)
            best_models.append(ML_algo)
            sub_y_test_pred = pd.DataFrame(ML_algo.predict(sub_X_test), index = sub_y_test.index,
                                           columns = ['sub_y_test_pred']) # convert in to data frame
            all_y_test_pred = pd.concat([all_y_test_pred, sub_y_test_pred])
                    
        all_y_test_pred = all_y_test_pred.sort_index()
        y_test = y_test.sort_index()
        pred_results.append(all_y_test_pred)

        # test mae in one-fold
        test_mae = mean_absolute_error(all_y_test_pred, y_test)
        test_scores[count] = test_mae
        
        # save best models
        with open(os.path.join(path, f'{model_name}_reduced_feature_best_models_{count}.pkl'), 'wb') as file:
            pickle.dump(best_models, file)
        
        count = count + 1
        print('\t test MAE:', test_mae)
        
    # mean accuracy for all random states
    print(f'overall test mean: {np.mean(test_scores)}')
    print(f'overall test std: {np.std(test_scores)}\n')

    # save test scores and prediction results
    with open(os.path.join(path, f'{model_name}_reduced_feature_test_scores.pkl'), 'wb') as file:
        pickle.dump(test_scores, file)
        
    with open(os.path.join(path, f'{model_name}_reduced_feature_pred_results.pkl'), 'wb') as file:
        pickle.dump(pred_results, file)
    
    return best_models

# %% [markdown]
# ## LASSO Result

# %%
model_name = 'lasso'
model = Lasso(max_iter=100000000)
param_grid = {'alpha': np.logspace(-2, 1, 15),
              'random_state': [42]}

start_time = time.time()
best_models = MLpipe_reduced_feature(X_other, y_other, groups_other, X_test, y_test, groups_test,
                                     preprocessor, model, param_grid, result_path, model_name)
print('LASSO reduced features model running time:', time.time()-start_time)
# Out:
# Fold 1 Reduced Features:
# 	 Train index: [     0      1      2 ... 743181 743182 743183] Val index: [ 743184  743185  743186 ... 1002231 1002232 1002233]
# 	 Train size: 743184 Val size: 259050
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.864886135817049
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.863475188786026
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.862385569110619
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.860803881702747
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.859857765453186
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.85841840229215
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.857890658944066
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.861620021938667
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 5.879269026032278
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 5.921345183441779
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 5.977688215392453
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 5.977688215392453
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 5.977688215392453
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 5.977688215392453
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 5.977688215392453
# 	 best model parameters for pattern 0:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 5.857890658944066
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.944368086472762
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.943248457473965
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.941857619251314
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.940711133997975
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.94046997541116
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.93911901590864
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.939202477321735
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.944289574174194
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 5.963238643233673
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.003023726280004
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.06033688102271
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.06033688102271
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.06033688102271
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.06033688102271
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.06033688102271
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.11787686347935872, 'random_state': 42}]
# 	 corresponding validation score: 5.93911901590864
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.551405067260188
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.550448894328561
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.549738112411968
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.549060995777827
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.548842716238223
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.54904198279738
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.551428501421536
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.558910951809437
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.57182587300003
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.604226211242897
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.676300095215629
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.694922062454239
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.694922062454239
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.694922062454239
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.694922062454239
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.07196856730011521, 'random_state': 42}]
# 	 corresponding validation score: 6.548842716238223
# 	 test MAE: 6.735454201267097
#
# Fold 2 Reduced Features:
# 	 Train index: [ 10505  10506  10507 ... 753961 753962 753963] Val index: [ 753964  753965  753966 ... 1013066 1013067 1013068]
# 	 Train size: 743459 Val size: 259105
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.948085984553517
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.946464594774447
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.945314384583836
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.943721537413524
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.942833081329148
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.941123624145445
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.940430111931641
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.943577050797058
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 5.960598768720269
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.002541972183774
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.059224937145593
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.059224937145593
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.059224937145593
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.059224937145593
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.059224937145593
# 	 best model parameters for pattern 0:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 5.940430111931641
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.019325225152603
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.017987951475233
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.016552616978525
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.015120659260409
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.0147126411657545
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.013279604861789
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.013217413068296
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.017886787473645
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.036433987951739
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.076269133686678
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.1339752635660085
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.1339752635660085
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.1339752635660085
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.1339752635660085
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.1339752635660085
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 6.013217413068296
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.658639462980171
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.657787407184332
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.657108977242308
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.656452418939563
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.6562866029270085
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.656562906415224
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.658969344855546
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.666691175580025
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.680024766029585
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.712968099263663
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.786290129475295
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.805211800321354
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.805211800321354
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.805211800321354
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.805211800321354
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.07196856730011521, 'random_state': 42}]
# 	 corresponding validation score: 6.6562866029270085
# 	 test MAE: 6.735362398635628
#
# Fold 3 Reduced Features:
# 	 Train index: [ 21010  21011  21012 ... 764741 764742 764743] Val index: [ 764744  764745  764746 ... 1023901 1023902 1023903]
# 	 Train size: 743734 Val size: 259160
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.995370287272097
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.99394647151912
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.99291461681734
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.9912724034268905
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.9906505301488995
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.9895740656683785
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.989236016289774
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.9927486097008345
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.010607414610524
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.055017755157782
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.112245011194506
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.112245011194506
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.112245011194506
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.112245011194506
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.112245011194506
# 	 best model parameters for pattern 0:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 5.989236016289774
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.06979203343976
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.068349266873581
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.067125693193723
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.065900753801745
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.065355715544544
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.064682384083004
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.0649670073422
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.069900107164385
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.089163188492109
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.1308822553481415
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.188884619331092
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.188884619331092
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.188884619331092
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.188884619331092
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.188884619331092
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.11787686347935872, 'random_state': 42}]
# 	 corresponding validation score: 6.064682384083004
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.727185914727919
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.726411147213119
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.725685252041704
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.725042718736879
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.724868802011661
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.725267438007431
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.727638402200571
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.735457710233325
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.748827189102113
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.782716826034121
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.857840818452952
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.877051530208568
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.877051530208568
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.877051530208568
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.877051530208568
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.07196856730011521, 'random_state': 42}]
# 	 corresponding validation score: 6.724868802011661
# 	 test MAE: 6.735419761949699
#
# Fold 4 Reduced Features:
# 	 Train index: [ 31515  31516  31517 ... 775521 775522 775523] Val index: [ 775524  775525  775526 ... 1034736 1034737 1034738]
# 	 Train size: 744009 Val size: 259215
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.188891474610617
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.1883096352209845
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.187627231652742
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.18689852426776
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.186798559290012
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.185574650382593
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.185554660394087
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.189823448740156
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.209462469634244
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.255666059817823
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.313939790585161
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.313939790585161
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.313939790585161
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.313939790585161
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.313939790585161
# 	 best model parameters for pattern 0:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 6.185554660394087
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.25837900024319
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.257123203376315
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.256969951682915
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.256802116239126
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.256375978459103
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.255728622651247
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.256437455011849
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.2622417959586745
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.283388361180987
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.326406017780452
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.385550299764982
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.385550299764982
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.385550299764982
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.385550299764982
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.385550299764982
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.11787686347935872, 'random_state': 42}]
# 	 corresponding validation score: 6.255728622651247
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 7.059890574739602
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 7.059226828593505
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 7.058531686001225
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 7.05816505298159
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 7.058022197953933
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 7.058333445776023
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 7.060838959071054
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 7.069032525447629
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 7.082700674291963
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 7.117378833985064
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 7.19454194825484
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 7.214526186020682
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 7.214526186020682
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 7.214526186020682
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 7.214526186020682
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.07196856730011521, 'random_state': 42}]
# 	 corresponding validation score: 7.058022197953933
# 	 test MAE: 6.735314347824146
# overall test mean: 6.735387677419143
# overall test std: 5.355157758185661e-05
#
# LASSO reduced features model running time: 3073.890172958374

# %% [markdown]
# ## Ridge Result

# %%
model_name = 'ridge'
model = Ridge()
param_grid = {'alpha': np.logspace(-2, 1, 15),
              'random_state': [42]}

start_time = time.time()
best_models = MLpipe_reduced_feature(X_other, y_other, groups_other, X_test, y_test, groups_test,
                                     preprocessor, model, param_grid, result_path, model_name)
print('Ridge reduced features model running time:', time.time()-start_time)
# Out:
# Fold 1 Reduced Features:
# 	 Train index: [     0      1      2 ... 743181 743182 743183] Val index: [ 743184  743185  743186 ... 1002231 1002232 1002233]
# 	 Train size: 743184 Val size: 259050
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.873671278218968
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.8735957993408086
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.8735051242526835
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.87339838578866
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.873276855838279
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.87313838914267
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.872976536159286
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.872793379349514
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 5.87260546453922
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 5.872453707817096
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 5.87241970043966
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 5.872641056186256
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 5.873072017587642
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 5.873719753991845
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 5.87444611761189
# 	 best model parameters for pattern 0:
#  [{'alpha': 1.3894954943731375, 'random_state': 42}]
# 	 corresponding validation score: 5.87241970043966
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.956764761183625
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.956743806393027
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.956715947720343
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.956681733721152
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.956645984862087
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.956613562009902
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.956588130227311
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.956571265799934
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 5.956562619217881
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 5.956564780415067
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 5.956585893406218
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 5.95664751030526
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 5.956764330881772
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 5.956936899032756
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 5.957113192298402
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.517947467923121, 'random_state': 42}]
# 	 corresponding validation score: 5.956562619217881
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.55618358796161
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.5561798747654825
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.556177688599034
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.556175366105581
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.5561731541983805
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.556174415394606
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.5561780154333835
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.556188385756001
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.556210734556861
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.556250790524025
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.556316891781813
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.556420505826257
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.556573927761908
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.556799742771577
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.557069175371352
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.07196856730011521, 'random_state': 42}]
# 	 corresponding validation score: 6.5561731541983805
# 	 test MAE: 6.7569192397690925
#
# Fold 2 Reduced Features:
# 	 Train index: [ 10505  10506  10507 ... 753961 753962 753963] Val index: [ 753964  753965  753966 ... 1013066 1013067 1013068]
# 	 Train size: 743459 Val size: 259105
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 5.955746375496882
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 5.955667968366815
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 5.955573481186564
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 5.955462171438039
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 5.955331748009228
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 5.9551805070682375
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 5.955001107735323
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 5.95479394330272
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 5.954579209036327
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 5.954378006025977
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 5.954282532133176
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 5.954441664812715
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 5.954811072777232
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 5.955417682843203
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 5.956117830913653
# 	 best model parameters for pattern 0:
#  [{'alpha': 1.3894954943731375, 'random_state': 42}]
# 	 corresponding validation score: 5.954282532133176
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.031345839189534
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.031326843723979
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.031301123934642
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.031271386400916
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.031241473720629
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.0312156036368245
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.031196396235718
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.031184923415534
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.031179074453067
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.031183214746158
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.031204015487984
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.031271632690925
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.0313832958255995
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.031555534671573
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.031727844541535
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.517947467923121, 'random_state': 42}]
# 	 corresponding validation score: 6.031179074453067
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.662859118078028
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.662839705143615
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.662821773322588
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.662805394535766
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.662792879492332
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.662783930365301
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.662781556564581
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.66278791165015
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.662806885718469
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.662844733359488
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.662911609020572
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.663018479359353
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.663181822155853
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.663418499120017
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.663706653333468
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 6.662781556564581
# 	 test MAE: 6.7567880411914025
#
# Fold 3 Reduced Features:
# 	 Train index: [ 21010  21011  21012 ... 764741 764742 764743] Val index: [ 764744  764745  764746 ... 1023901 1023902 1023903]
# 	 Train size: 743734 Val size: 259160
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.010319646761938
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.010230544074127
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.010123901718655
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.010004082733056
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.009869768689775
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.009712369990154
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.0095288550310775
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.009311087111004
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.009073705154139
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.008856753659351
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.008737192267628
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.008780379316174
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.008891217441483
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.0089976178597855
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.008946695893216
# 	 best model parameters for pattern 0:
#  [{'alpha': 1.3894954943731375, 'random_state': 42}]
# 	 corresponding validation score: 6.008737192267628
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.088393983669741
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.088382285683986
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.0883663942839155
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.088348270848737
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.08833276080216
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.088320367111593
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.088307849109595
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.08829398878932
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.0882748835330505
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.088241024621928
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.088178338505583
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.088073667951125
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.087892635220759
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.087602447477333
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.087151437066052
# 	 best model parameters for pattern 1:
#  [{'alpha': 10.0, 'random_state': 42}]
# 	 corresponding validation score: 6.087151437066052
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.73335292720548
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.73333130233711
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.733307382765268
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.733280456392225
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.733249908700595
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.733221560931556
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.7331958186533845
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.733176517855519
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.733166898609504
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.733168184193058
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.733182205848158
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.7332209832594385
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.733300074884519
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.733433345915202
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.7336113861495495
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.517947467923121, 'random_state': 42}]
# 	 corresponding validation score: 6.733166898609504
# 	 test MAE: 6.759876255041067
#
# Fold 4 Reduced Features:
# 	 Train index: [ 31515  31516  31517 ... 775521 775522 775523] Val index: [ 775524  775525  775526 ... 1034736 1034737 1034738]
# 	 Train size: 744009 Val size: 259215
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.198157847854114
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.198048656709134
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.197917474176455
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.197763436160757
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.19758424578009
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.197377135081364
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.197140073525943
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.1968890906438165
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.196635419531141
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.196426880840834
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.196346031646109
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.196566007531046
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.19704502443107
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.197736428980005
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.19850057391694
# 	 best model parameters for pattern 0:
#  [{'alpha': 1.3894954943731375, 'random_state': 42}]
# 	 corresponding validation score: 6.196346031646109
# 	 working on unique pattern 1
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 6.272070870109613
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 6.272040196674436
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 6.272001500960383
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 6.271957771357018
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 6.271915725821653
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 6.27188268476937
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 6.271863978506017
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 6.27186370985544
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 6.271886875861643
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 6.27193920104474
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 6.272031537341409
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 6.272188337272039
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 6.272417304253251
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 6.272703357342606
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 6.272987173375537
# 	 best model parameters for pattern 1:
#  [{'alpha': 0.31622776601683794, 'random_state': 42}]
# 	 corresponding validation score: 6.27186370985544
# 	 working on unique pattern 2
# 		 params: {'random_state': 42, 'alpha': 0.01}
# 		 val_score: 7.064129379017611
# 		 params: {'random_state': 42, 'alpha': 0.016378937069540637}
# 		 val_score: 7.064102177333718
# 		 params: {'random_state': 42, 'alpha': 0.02682695795279726}
# 		 val_score: 7.064075449144935
# 		 params: {'random_state': 42, 'alpha': 0.043939705607607904}
# 		 val_score: 7.06405152091794
# 		 params: {'random_state': 42, 'alpha': 0.07196856730011521}
# 		 val_score: 7.064033062271631
# 		 params: {'random_state': 42, 'alpha': 0.11787686347935872}
# 		 val_score: 7.064017835840497
# 		 params: {'random_state': 42, 'alpha': 0.19306977288832497}
# 		 val_score: 7.064009479619294
# 		 params: {'random_state': 42, 'alpha': 0.31622776601683794}
# 		 val_score: 7.06401337671439
# 		 params: {'random_state': 42, 'alpha': 0.517947467923121}
# 		 val_score: 7.064033748543244
# 		 params: {'random_state': 42, 'alpha': 0.8483428982440717}
# 		 val_score: 7.064078977527815
# 		 params: {'random_state': 42, 'alpha': 1.3894954943731375}
# 		 val_score: 7.064155542214003
# 		 params: {'random_state': 42, 'alpha': 2.2758459260747887}
# 		 val_score: 7.064277754457075
# 		 params: {'random_state': 42, 'alpha': 3.727593720314938}
# 		 val_score: 7.064468055877524
# 		 params: {'random_state': 42, 'alpha': 6.105402296585327}
# 		 val_score: 7.064737424059178
# 		 params: {'random_state': 42, 'alpha': 10.0}
# 		 val_score: 7.065059020182779
# 	 best model parameters for pattern 2:
#  [{'alpha': 0.19306977288832497, 'random_state': 42}]
# 	 corresponding validation score: 7.064009479619294
# 	 test MAE: 6.757298380341011
# overall test mean: 6.757720479085643
# overall test std: 0.001258666177864995
#
# Ridge reduced features model running time: 896.2735764980316
