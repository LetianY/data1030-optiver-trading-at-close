# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import gc, time, warnings, joblib, pickle
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
from itertools import combinations
from warnings import simplefilter

pd.set_option('display.float_format', lambda x: '%.4f' % x)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)

warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
# Out:
# /kaggle/input/data1030-optiver-trading-at-close/test_dataset.pkl
# /kaggle/input/data1030-optiver-trading-at-close/train_val_dataset.pkl

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_absolute_error

from mlxtend.evaluate.time_series import (
    GroupTimeSeriesSplit,
    plot_splits,
    print_cv_info,
    print_split_info,
)

# %%
# Load Data
data_folder = '/kaggle/input/data1030-optiver-trading-at-close/'
# data_folder = '../data/preprocessed/'

with open(os.path.join(data_folder, 'train_val_dataset.pkl'), 'rb') as file:
    train_val_dataset = pickle.load(file)
    
with open(os.path.join(data_folder, 'test_dataset.pkl'), 'rb') as file:
    test_dataset = pickle.load(file)

X_other, y_other, groups_other = train_val_dataset['X_other'], train_val_dataset['y_other'], train_val_dataset['groups_other']
X_test, y_test, groups_test, submission_id = test_dataset['X_test'], test_dataset['y_test'], test_dataset['groups_test'], test_dataset['submission_id']

# collect which encoder to use on each feature
onehot_ftrs = ['imbalance_buy_sell_flag', 'stock_id']
std_ftrs = ['seconds_in_bucket', 'imbalance_size', 'reference_price', 'matched_size', 
            'far_price', 'near_price', 'bid_price', 'bid_size', 'ask_price', 'ask_size', 
            'wap', 'lagged_target_1d_0', 'lagged_target_1d_10', 'lagged_target_1d_20', 
            'lagged_target_1d_30', 'lagged_target_1d_40', 'lagged_target_1d_50', 
            'lagged_target_1d_60', 'lagged_target_1d_70', 'lagged_target_1d_80', 
            'lagged_target_1d_90', 'lagged_target_1d_100', 'lagged_target_1d_110', 
            'lagged_target_1d_120', 'lagged_target_1d_130', 'lagged_target_1d_140', 
            'lagged_target_1d_150', 'lagged_target_1d_160', 'lagged_target_1d_170', 
            'lagged_target_1d_180', 'lagged_target_1d_190', 'lagged_target_1d_200', 
            'lagged_target_1d_210', 'lagged_target_1d_220', 'lagged_target_1d_230', 
            'lagged_target_1d_240', 'lagged_target_1d_250', 'lagged_target_1d_260', 
            'lagged_target_1d_270', 'lagged_target_1d_280', 'lagged_target_1d_290', 
            'lagged_target_1d_300', 'lagged_target_1d_310', 'lagged_target_1d_320', 
            'lagged_target_1d_330', 'lagged_target_1d_340', 'lagged_target_1d_350', 
            'lagged_target_1d_360', 'lagged_target_1d_370', 'lagged_target_1d_380', 
            'lagged_target_1d_390', 'lagged_target_1d_400', 'lagged_target_1d_410', 
            'lagged_target_1d_420', 'lagged_target_1d_430', 'lagged_target_1d_440', 
            'lagged_target_1d_450', 'lagged_target_1d_460', 'lagged_target_1d_470', 
            'lagged_target_1d_480', 'lagged_target_1d_490', 'lagged_target_1d_500', 
            'lagged_target_1d_510', 'lagged_target_1d_520', 'lagged_target_1d_530', 
            'lagged_target_1d_540', 'volume', 'mid_price', 'liquidity_imbalance', 
            'matched_imbalance', 'size_imbalance', 'reference_price_far_price_imb', 
            'reference_price_near_price_imb', 'reference_price_ask_price_imb', 
            'reference_price_bid_price_imb', 'reference_price_wap_imb', 'far_price_near_price_imb', 
            'far_price_ask_price_imb', 'far_price_bid_price_imb', 'far_price_wap_imb', 
            'near_price_ask_price_imb', 'near_price_bid_price_imb', 'near_price_wap_imb', 
            'ask_price_bid_price_imb', 'ask_price_wap_imb', 'bid_price_wap_imb', 'price_spread', 
            'price_pressure', 'market_urgency', 'depth_pressure', 'all_prices_mean', 
            'all_sizes_mean', 'all_prices_std', 'all_sizes_std', 'all_prices_skew', 
            'all_sizes_skew', 'all_prices_kurt', 'all_sizes_kurt', 'dow', 'seconds', 'minute']

# collect all the encoders
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(sparse_output=False,handle_unknown='ignore'), onehot_ftrs),
        ('std', StandardScaler(), std_ftrs)])

model_save_path = 'result'
if not os.path.exists(model_save_path):
    os.makedirs(model_save_path)
    
result_path = '/kaggle/working/result/'
# result_path = '../result/'

# %% [markdown]
# # Pipeline

# %%
from  sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
def MLpipe_reduced_feature(X_other, y_other, groups_other, X_test, y_test, groups_test,
                           preprocessor, model, param_grid, path, model_Name):
    prep = Pipeline(steps=[('preprocessor', preprocessor)])

    n_split = 4
    count = 0
    test_scores = np.zeros(n_split)
    pred_results = []

    # Split train-val data
    len_group_other = groups_other.nunique()
    gts = GroupTimeSeriesSplit(test_size=int(len_group_other*0.25), n_splits=n_split)

    for i_train, i_val in gts.split(X_other, y_other, groups_other):
        print(f'\nFold {count+1} Reduced Features:')
        best_models = []
        
        print("\t Train index:", i_train, "Val index:", i_val)
        print("\t Train size:", len(i_train), "Val size:", len(i_val))
        X_train, y_train, groups_train = X_other.iloc[i_train], y_other.iloc[i_train], groups_other.iloc[i_train]
        X_val, y_val, groups_val = X_other.iloc[i_val], y_other.iloc[i_val], groups_other.iloc[i_val]
        
        X_train_preprocessed = prep.fit_transform(X_train)
        feature_names = preprocessor.get_feature_names_out()
        
        # parameter Searching
        pg = ParameterGrid(param_grid)
        scores = np.zeros(len(pg))
        
        print('\t Preparing datasets...')
        df_train = pd.DataFrame(data = X_train_preprocessed, columns = feature_names, index=y_train.index)
        del X_train_preprocessed, X_train
        gc.collect()
        
        X_val_preprocessed = prep.transform(X_val)
        df_val = pd.DataFrame(data = X_val_preprocessed, columns = feature_names, index=y_val.index)
        del X_val_preprocessed, X_val
        gc.collect()
        
        X_test_preprocessed = prep.transform(X_test)
        df_test = pd.DataFrame(data = X_test_preprocessed, columns = feature_names, index=y_test.index)

        # Free up memory
        del X_test_preprocessed
        gc.collect()

        # reduced feature
        # find all unique patterns of missing value in test set
        mask = df_test.isnull()
        unique_rows = np.array(np.unique(mask, axis=0))
        all_y_test_pred = pd.DataFrame()
        print('\t there are', len(unique_rows), 'unique missing value patterns.')

        # divide test sets into subgroups according to the unique patterns
        for i in range(len(unique_rows)):
            print ('\t working on unique pattern', i)
            ## generate X_test subset that matches the unique pattern i: optimized code
            index_subset = df_test[mask.eq(unique_rows[i], axis=1).all(axis=1)].index
            sub_X_test = df_test.loc[index_subset] 
            sub_X_test = sub_X_test[df_test.columns[~unique_rows[i]]] # drop nan columns
            sub_y_test = y_test.loc[index_subset]

            ## prepare train-val subset
            # 1.cut the feature columns that have nans in the according sub_X_test
            sub_X_train = df_train[df_train.columns[~unique_rows[i]]].copy()
            sub_X_val = df_val[df_val.columns[~unique_rows[i]]].copy()
            # 2.cut the rows in the sub_X_train and sub_X_CV that have any nans
            sub_X_train = sub_X_train.dropna()
            sub_X_val = sub_X_val.dropna()   
            # 3.cut the sub_Y_train and sub_y_CV accordingly
            sub_y_train = y_train.loc[sub_X_train.index]
            sub_y_val = y_val.loc[sub_X_val.index]

            # run ML algo
            # change to 1-D array
            sub_y_train_array = sub_y_train.values.ravel()
            sub_y_val_array = sub_y_val.values.ravel()
            sub_y_test_array = sub_y_test.values.ravel()

            # run model
            ML_algo = model
            pg = ParameterGrid(param_grid)
            val_scores = np.zeros(len(pg))
                
            for p in range(len(pg)):
                params = pg[p]
                print('\t\t params:', params)
                ML_algo.set_params(**params)
                eval_set = [(sub_X_val, sub_y_val_array)]
                ML_algo.fit(sub_X_train, sub_y_train_array,
                            eval_set=eval_set, early_stopping_rounds=50,verbose=False)
                sub_y_val_pred = ML_algo.predict(sub_X_val)
                val_scores[p] = mean_absolute_error(sub_y_val_array, sub_y_val_pred)
                print('\t\t val_score:', val_scores[p])
            
            best_params = np.array(pg)[val_scores == np.min(val_scores)]
            print(f'\t best model parameters for pattern {i}:\n', best_params)
            print('\t corresponding validation score:', np.min(val_scores))
                
            ML_algo.set_params(**best_params[0])
            ML_algo.fit(sub_X_train, sub_y_train_array,
                        eval_set=eval_set, early_stopping_rounds=50, verbose=False)
            best_models.append(ML_algo)
            sub_y_test_pred = pd.DataFrame(ML_algo.predict(sub_X_test), index = sub_y_test.index,
                                           columns = ['sub_y_test_pred']) # convert in to data frame
            all_y_test_pred = pd.concat([all_y_test_pred, sub_y_test_pred])
                    
        all_y_test_pred = all_y_test_pred.sort_index()
        y_test = y_test.sort_index()
        pred_results.append(all_y_test_pred)

        # test mae in one-fold
        test_mae = mean_absolute_error(all_y_test_pred, y_test)
        test_scores[count] = test_mae
        print('\t test MAE:', test_mae)
        
        # save best models
        with open(os.path.join(path, f'{model_name}_reduced_feature_best_models_{count}.pkl'), 'wb') as file:
            pickle.dump(best_models, file)
        
        count = count + 1
        
    # mean accuracy for all random states
    print(f'overall test mean: {np.mean(test_scores)}')
    print(f'overall test std: {np.std(test_scores)}\n')

    # save best models for the last fold
    with open(os.path.join(path, f'{model_name}_reduced_feature_test_scores.pkl'), 'wb') as file:
        pickle.dump(test_scores, file)

    with open(os.path.join(path, f'{model_name}_reduced_feature_pred_results.pkl'), 'wb') as file:
        pickle.dump(pred_results, file)
    
    return best_models

# %% [markdown]
# ## XGB

# %%
from xgboost import XGBRegressor

model_name = 'xgb'
model = XGBRegressor()
param_grid = {"learning_rate": [0.01],
              "n_estimators": [6000],
              'reg_alpha': [0.1, 0.5, 1],
              'reg_lambda': [1, 2],
              "missing": [np.nan], 
              "max_depth": [1, 3, 7, 11],
              "colsample_bytree": [0.9],              
              "subsample": [0.66],
              "eval_metric": ['mae'],
              "seed": [42],
              "n_thread": [-1],
              "tree_method": ['gpu_hist'],
              "verbosity": [0]
             }

start_time = time.time()
best_models = MLpipe_reduced_feature(X_other, y_other, groups_other, X_test, y_test, groups_test,
                                     preprocessor, model, param_grid, result_path, model_name)
print('XGB reduced features model running time:', time.time()-start_time)
# Out:
# Fold 1 Reduced Features:
# 	 Train index: [     0      1      2 ... 743181 743182 743183] Val index: [ 743184  743185  743186 ... 1002231 1002232 1002233]
# 	 Train size: 743184 Val size: 259050
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.860317860795453
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.860322733104668
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.860317799300453
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.860413729682331
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.860317716759166
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.860339500502424
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.85031210379465
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.850490906322451
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.850322516164711
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.850918569987738
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.850546560855649
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.850611531452311
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.846905065582181
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.845877175808765
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.847445954918951
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.846493336328428
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.8470844456520386
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.846624768473991
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.85103310526286
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.850757687446059
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.851049395417658
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.849945361912898
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.851213567923806
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.8506543944626825
# 	 best model parameters for pattern 0:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.1, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 5.845877175808765
# 	 working on unique pattern 1
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942210356994745
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942011728802405
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942210230820049
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.9420114597423375
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942210067768191
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.94191439438128
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.935567233739016
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.934756376058961
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.935294391700818
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.934744193486671
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.935194007208756
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.9350326532617155
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.929187144751772
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.927440801429363
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.928044628604449
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.928068720031911
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.927821418219836
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.927388116231065
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.937496122461844
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.933214950911872
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.937512458429718
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.9330203717759575
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.936605397946679
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.93322521738742
# 	 best model parameters for pattern 1:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 1, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 5.927388116231065
# 	 working on unique pattern 2
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.551581753572476
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.552258068214436
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.551581697295207
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.552327105996404
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.551581615347704
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.55232716464324
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.5460939345548494
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.545817016319151
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.546064429944909
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.545665590055811
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.546021638470618
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.545859086598988
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.548294282699697
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.546511967829614
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.548365122480666
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.5465314285889304
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.548461539991021
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.547221039596418
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.5538885750647005
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.549929441842758
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.553232038701779
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.5498036086513824
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.55288312728069
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.549172185121314
# 	 best model parameters for pattern 2:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 3, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.5, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 6.545665590055811
# 	 test MAE: 6.740288918583766
#
# Fold 2 Reduced Features:
# 	 Train index: [ 10505  10506  10507 ... 753961 753962 753963] Val index: [ 753964  753965  753966 ... 1013066 1013067 1013068]
# 	 Train size: 743459 Val size: 259105
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.94226846204213
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942292443259364
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942268356682303
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942297231014212
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942268227397704
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.942294879037272
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.933813409926921
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.933740286200989
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.93384896208109
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.9337220258905345
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.93389743844476
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.9337791053050895
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.932289888542781
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.930701488799276
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.93271526830903
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.930873377649904
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.932540472147991
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.931396837749424
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.937309855844242
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.934753318312986
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.937279445398626
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.935759986209362
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.937316600167852
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.93479111163415
# 	 best model parameters for pattern 0:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.1, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 5.930701488799276
# 	 working on unique pattern 1
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.015404433255436
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.0154066183115775
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.015372150773354
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.015406357453036
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.01539193890122
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.015406042759462
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.00961603571014
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.008932069234964
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.009412837800738
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.008940116038087
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.009378005039558
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.0089637603274255
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.003906809607217
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.003756404512899
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.005095758136742
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.003733943905261
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.004626504519857
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.00402147277096
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.0127461065197565
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.0088320309391765
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.013138873515437
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.010845369766819
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.012133305796181
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.009843026786675
# 	 best model parameters for pattern 1:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.5, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 6.003733943905261
# 	 working on unique pattern 2
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.6601670981805645
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.66013710624177
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.660167147717787
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.660130860792474
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.660167207226362
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.660107908052144
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.656039259972365
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.655493519836128
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.655758645321873
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.65554379873997
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.655728682336883
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.656092686554406
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.657593774507856
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.656397444647697
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.657716172900844
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.6564549702073705
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.657737146298647
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.656119430338688
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.663331463328484
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.6601584469966255
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.663514366037339
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.660084110454386
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.663708423016003
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.660361302593196
# 	 best model parameters for pattern 2:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 3, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.1, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 6.655493519836128
# 	 test MAE: 6.739273594890714
#
# Fold 3 Reduced Features:
# 	 Train index: [ 21010  21011  21012 ... 764741 764742 764743] Val index: [ 764744  764745  764746 ... 1023901 1023902 1023903]
# 	 Train size: 743734 Val size: 259160
# 	 Preparing datasets...
# 	 there are 3 unique missing value patterns.
# 	 working on unique pattern 0
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.991010326294443
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.990930964535085
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.990997123990367
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.990932713602533
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.990946238822584
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.990928061461242
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.981865294119444
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.981691310900915
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 5.981839600356779
# ...
# 		 val_score: 6.175888628942247
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.17823896931737
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.1757359179760805
# 	 best model parameters for pattern 0:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.5, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 6.171148985095265
# 	 working on unique pattern 1
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.258859033662145
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.258836709638795
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.258859072915763
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.258836747632958
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.258837557865477
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.258836798028372
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.247411555411909
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.246669532802353
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.247144814702945
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.247455892880288
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.247492574157576
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.246794907172532
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.245005876911591
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.243906970959183
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.244755001759211
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.244753997385497
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.246239988151932
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.2441986266326746
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.2524664142739494
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.24839937871267
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.25147919516008
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.248345761546306
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.25186854583188
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 6.249365015358104
# 	 best model parameters for pattern 1:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 0.1, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 6.243906970959183
# 	 working on unique pattern 2
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.061680733425472
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.06172416428734
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.061723804263764
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.06172428245775
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.061723953368378
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 1, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.061724432582939
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.059006585729309
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.058979369943464
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.059035773156041
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.0589284039408655
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.0590968341921325
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 3, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.058962038645054
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.059245676555209
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.057341703912974
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.059294818339661
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.057129689593037
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.059129178362644
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 7, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.057017050802045
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.063477812516202
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.060911685332564
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.063700406495463
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 0.5, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.061926607249661
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 1, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.064097848010005
# 		 params: {'verbosity': 0, 'tree_method': 'gpu_hist', 'subsample': 0.66, 'seed': 42, 'reg_lambda': 2, 'reg_alpha': 1, 'n_thread': -1, 'n_estimators': 6000, 'missing': nan, 'max_depth': 11, 'learning_rate': 0.01, 'eval_metric': 'mae', 'colsample_bytree': 0.9}
# 		 val_score: 7.061067621062447
# 	 best model parameters for pattern 2:
#  [{'colsample_bytree': 0.9, 'eval_metric': 'mae', 'learning_rate': 0.01, 'max_depth': 7, 'missing': nan, 'n_estimators': 6000, 'n_thread': -1, 'reg_alpha': 1, 'reg_lambda': 2, 'seed': 42, 'subsample': 0.66, 'tree_method': 'gpu_hist', 'verbosity': 0}]
# 	 corresponding validation score: 7.057017050802045
# 	 test MAE: 6.7371280197598855
# overall test mean: 6.738884228337913
# overall test std: 0.0011413218275947614
#
# XGB reduced features model running time: 5821.885423183441
